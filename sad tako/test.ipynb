# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Ridge
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.ensemble import StackingRegressor
from xgboost import XGBRegressor
import joblib

import numpy as np
import pandas as pd
import os

import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from sklearn.svm import SVC
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import VotingClassifier

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.callbacks import EarlyStopping

# %%
#設定LSTM往前看的筆數和預測筆數
LookBackNum = 12 #LSTM往前看的筆數
ForecastNum = 48 #預測筆數

#載入訓練資料
DataName = os.getcwd()+'\ExampleTrainData(AVG)\AvgDATA_17.csv'
SourceData = pd.read_csv(DataName, encoding='utf-8')

#迴歸分析 選擇要留下來的資料欄位
#(風速,大氣壓力,溫度,濕度,光照度)
#(發電量)
Regression_X_train = SourceData[['WindSpeed(m/s)','Pressure(hpa)','Temperature(°C)','Humidity(%)','Sunlight(Lux)']].values
Regression_y_train = SourceData[['Power(mW)']].values

#LSTM 選擇要留下來的資料欄位
#(風速,大氣壓力,溫度,濕度,光照度)
AllOutPut = SourceData[['WindSpeed(m/s)','Pressure(hpa)','Temperature(°C)','Humidity(%)','Sunlight(Lux)']].values

#正規化
LSTM_MinMaxModel = MinMaxScaler().fit(AllOutPut)
AllOutPut_MinMax = LSTM_MinMaxModel.transform(AllOutPut)
Regression_X_train_norm = LSTM_MinMaxModel.fit_transform(Regression_X_train)

X_train = []
y_train = []

#設定每i-12筆資料(X_train)就對應到第i筆資料(y_train)
for i in range(LookBackNum,len(AllOutPut_MinMax)):
  X_train.append(AllOutPut_MinMax[i-LookBackNum:i, :])
  y_train.append(AllOutPut_MinMax[i, :])


X_train = np.array(X_train)
y_train = np.array(y_train)

# Reshaping
#(samples 是訓練樣本數量,timesteps 是每個樣本的時間步長,features 是每個時間步的特徵數量)
X_train = np.reshape(X_train,(X_train.shape [0], X_train.shape [1], 5))

# %% [markdown]
# train model

# %%
regressor = Sequential ()

regressor.add(LSTM(units = 128, return_sequences = True, input_shape = (X_train.shape[1], 5)))

regressor.add(LSTM(units = 64))

regressor.add(Dropout(0.2))

# output layer
regressor.add(Dense(units = 5))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

#開始訓練
regressor.fit(X_train, y_train, epochs = 100, batch_size = 128)

#保存模型
from datetime import datetime
regressor.save('WheatherLSTM.h5')
print('Model Saved')
# Out:
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.0786
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0164
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0121
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0106
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0088
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0085
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0076
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0071
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0067
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0061
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0061
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0060
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0059
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0055
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0050
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0054
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0056
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0054
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0052
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0048
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0051
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0051
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0049
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0050
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0048
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0047
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0048
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0051
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0045
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0047
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0046
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0043
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0044
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0044
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0042
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0045
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0043
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0044
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0045
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0044
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0043
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0042
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0044
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0045
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0040
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0042
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0043
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0042
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0038
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0039
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0041
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0040
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0043
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0037
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0040
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0039
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0039
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0038
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0037
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0041
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0037
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0041
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0038
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0038
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0037
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0038
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0035
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0038
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0034
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0037
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0037
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0041
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0037
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035
# Epoch 75/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0036
# Epoch 76/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0035
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0036
# Epoch 79/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035
# Epoch 80/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0036
# Epoch 81/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0037
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0034
# Epoch 83/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0034
# Epoch 84/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0034
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0036
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0032
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0032
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0036
# Epoch 89/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035
# Epoch 90/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0030
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035
# Epoch 92/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0031
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0032
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0031
# Epoch 95/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0031
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0032
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0032
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0032
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0035
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved

# %% [markdown]
# lstm模型初步預測

# %%
# 使用 LSTM 模型預測特徵
lstm_features = regressor.predict(X_train)

# 融合特徵
stack_input = np.hstack([Regression_X_train_norm[LookBackNum:], lstm_features])

# 分割資料集
X_train_stack, X_test_stack, y_train_stack, y_test_stack = train_test_split(stack_input, Regression_y_train[LookBackNum:], test_size=0.2, random_state=42)

# 建立基礎模型
ridge = LinearRegression()
xgb = XGBRegressor(n_estimators=100, learning_rate=0.1)

# 建立堆疊回歸模型
stacking_regressor = StackingRegressor(
    estimators=[('ridge', ridge), ('xgb', xgb)],
    final_estimator=Ridge()
)

# 訓練堆疊回歸模型
stacking_regressor.fit(X_train_stack, y_train_stack)

# 評估模型
score = stacking_regressor.score(X_test_stack, y_test_stack)
joblib.dump(stacking_regressor, 'stacking_regressor.pkl')
print(f'Stacking Regressor R^2 score: {score}')
# Out:
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# Stacking Regressor R^2 score: 0.9613281998677713

# %% [markdown]
# stacking 最終預測

# %%
#載入模型
regressor = load_model('WheatherLSTM.h5')

# 載入測試資料
DataName = os.getcwd() + r'\ExampleTestData\upload.csv'
SourceData = pd.read_csv(DataName, encoding='utf-8')
target = ['序號']
EXquestion = SourceData[target].values

inputs = []  # 存放參考資料
PredictOutput = []  # 存放預測值

LookBackNum = 12
ForecastNum = 48
expected_features = 5

count = 0
while count < len(EXquestion):
    print('count : ', count)
    LocationCode = int(EXquestion[count])  # 裝置編號
    strLocationCode = str(LocationCode)[-2:]  # 裝置編號字串
    if LocationCode < 10:
        strLocationCode = '0' + str(LocationCode)

    DataName = os.getcwd() + '\ExampleTrainData(IncompleteAVG)\IncompleteAvgDATA_' + strLocationCode + '.csv'
    SourceData1 = pd.read_csv(DataName, encoding='utf-8')
    ReferTitle = SourceData1[['Serial']].values
    ReferData = SourceData1[['WindSpeed(m/s)', 'Pressure(hpa)', 'Temperature(°C)', 'Humidity(%)', 'Sunlight(Lux)']].values

    inputs = []  # 重置存放參考資料

    # 找到相同的一天，把12個資料都加進inputs
    for DaysCount in range(len(ReferTitle)):
        if str(int(ReferTitle[DaysCount]))[:8] == str(int(EXquestion[count]))[:8]:
            inputs.append(ReferData[DaysCount])

    # 確保 inputs 的長度一致
    while len(inputs) < LookBackNum:
        inputs.append([0] * expected_features)  # 使用零填充

    # 用迴圈不斷使新的預測值塞入參考資料，並預測下一筆資料
    for i in range(ForecastNum):

        # 將新的預測值加入參考資料(用自己的預測值往前看)
        if i > 0:
            inputs.append(PredictOutput[i - 1])

        # 切出新的參考資料12筆(往前看12筆)
        X_test = []
        X_test.append(inputs[0 + i:LookBackNum + i])

        # Reshaping
        NewTest = np.array(X_test)
        NewTest = np.reshape(NewTest, (NewTest.shape[0], NewTest.shape[1], expected_features))  # 確保有5個特徵

        # 確保 NewTest 的形狀與 LSTM 模型期望的形狀一致
        print(f"NewTest shape: {NewTest.shape}")

        predicted = regressor.predict(NewTest)
        PredictOutput.append(round(predicted[0, 0], 2))

    # 每次預測都要預測48個，因此加48個會切到下一天
    count += 48
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# count :  0
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# count :  48
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# count :  96
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# count :  144
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# count :  192
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# count :  240
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# count :  288
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# count :  336
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# count :  384
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# count :  432
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# count :  480
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# count :  528
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# count :  576
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# count :  624
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# count :  672
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# count :  720
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ...
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# count :  9360
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# count :  9408
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# count :  9456
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# count :  9504
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# count :  9552
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# NewTest shape: (1, 12, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step

# %%
#載入訓練資料
DataName = os.getcwd()+'\Training data\L17_Train.csv'
SourceData = pd.read_csv(DataName, encoding='utf-8')

Regression_X_train = SourceData[['WindSpeed(m/s)','Pressure(hpa)','Temperature(°C)','Humidity(%)','Sunlight(Lux)']].values

# %%
print(f"Regression_X_train_norm shape: {Regression_X_train_norm.shape}")
print(f"lstm_features shape: {lstm_features.shape}")
print(f"Regression_X shape: {Regression_X_train.shape}")
# Out:
# Regression_X_train_norm shape: (5202, 5)
# lstm_features shape: (9600, 1)
# Regression_X shape: (92802, 5)

# %%
# 將 LSTM 模型的預測結果作為新的特徵
lstm_features = np.array(PredictOutput).reshape(-1, 1)

# 準備堆疊模型的輸入特徵
# 假設 Regression_X_norm 是之前正規化過的特徵
test_features = np.hstack([Regression_X_train[LookBackNum:], lstm_features])

# 使用堆疊模型進行最終預測
stacking_predictions = stacking_regressor.predict(test_features)

# %%
#載入訓練資料
DataName = os.getcwd()+'\output_high_score.csv'
SourceData = pd.read_csv(DataName, encoding='utf-8')

PredictOutput = SourceData['答案']
target = SourceData['target']

# %%
print(Regression_X_train_norm[LookBackNum:].shape)
print(lstm_features.shape)
# Out:
# (5190, 5)
# (9600, 1)

# %%
# 改成一致的行數
lstm_features_aligned = lstm_features[:5190]

# 合併成 stack model 的輸入
stack_input = np.hstack([Regression_X_train_norm[LookBackNum:], lstm_features_aligned])

# 接著再進行資料切分與堆疊模型的訓練
X_train_stack, X_test_stack, y_train_stack, y_test_stack = train_test_split(
    stack_input, Regression_y_train[LookBackNum:], test_size=0.2, random_state=42
)

# 訓練並評估
stacking_regressor = StackingRegressor(
    estimators=[('ridge', LinearRegression()), ('xgb', XGBRegressor())],
    final_estimator=Ridge()
)
stacking_regressor.fit(X_train_stack, y_train_stack)
score = stacking_regressor.score(X_test_stack, y_test_stack)
print(f'Stacking Regressor R^2 score: {score}')
# Out:
# Stacking Regressor R^2 score: 0.9534401604865047

# %%
# 使用堆疊模型進行最終預測


# 將預測結果寫成新的CSV檔案
df = pd.DataFrame(stacking_predictions, columns=['答案'])
df['target'] = SourceData['target']
df = df[['target', '答案']]

# 將 DataFrame 寫入 CSV 檔案
df.to_csv('output.csv', index=False, header=True)
print('Output CSV File Saved')
# Out:
# Output CSV File Saved
